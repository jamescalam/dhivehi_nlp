# %%
from transformers import (
    pipeline,
    PreTrainedTokenizerFast
)

tokenizer = PreTrainedTokenizerFast.from_pretrained('bert-base-dv')

fill_mask = pipeline(
    'fill-mask',
    model='bert-base-dv',
    tokenizer=tokenizer
)

# %% [markdown]
# We will read in some simple examples.

# %%
read_dv = open('../data/entodv.tsv', encoding='utf-8')
samples = []
for i, row in enumerate(read_dv):
    en, dv = row.split('\t')
    samples.append(dv)
    if i >= 5: break

# %%
from random import randint
# mask a random token (that is not CLS or SEP)
def add_mask(text):
    tokens = tokenizer(text, add_special_tokens=False)['input_ids']
    i = randint(1, len(tokens)-2)
    tokens[i] = tokenizer.mask_token_id
    mask_text = tokenizer.decode(tokens)
    return mask_text

# %%
samples = [(sentence, add_mask(sentence)) for sentence in samples]

# %%
samples
# Out:
# [('ބޭންކު ހެދީ ވާދަވެރިކަން ބޮޑުކޮށް، އިންޓަރެސްޓް ކުޑަ ކުރަން\n',
#   'ބޭންކު ހެދީ [MASK] ބޮޑުކޮށް ، އިންޓަރެސްޓް ކުޑަ ކުރަން'),
#  ('ރާއްޖޭގައި އިތުރު ބޭންކެއް ހެދުމުގެ މަގުސަދަކީ ބޭންކިން ދާއިރާގެ ވާދަވެރިކަން ބޮޑުކޮށް، އިންޓަރެސްޓް ރޭޓް ކުޑަ ކުރުމަށް ބާރު އަޅަން ކަމަށް ކޮމާޝަލް ބޭންކް އޮފް މޯލްޑިވްސް (ސީބީއެމް)ގެ އެއް ހިއްސާދާރު އަދި މަޝްހޫރު ވިޔަފާރިވެރިޔާ، ޗަމްޕާ ހުސެއިން އަފީފު މިއަދު ވިދާޅުވެއްޖެ އެވެ.\n',
#   'ރާއްޖޭގައި އިތުރު ބޭންކެއް ހެދުމުގެ މަގުސަދަކީ ބޭންކިން ދާއިރާގެ ވާދަވެރިކަން ބޮޑުކޮށް ، [MASK] ރޭޓް ކުޑަ ކުރުމަށް ބާރު އަޅަން ކަމަށް ކޮމާޝަލް ބޭންކް އޮފް މޯލްޑިވްސް ( ސީބީއެމް ) ގެ އެއް ހިއްސާދާރު އަދި މަޝްހޫރު ވިޔަފާރިވެރިޔާ ، ޗަމްޕާ ހުސެއިން އަފީފު މިއަދު ވިދާޅުވެއްޖެ އެވެ.'),
#  ('އަވަސް އަށް ދެއްވި ހާއްސަނ އިންޓަވިއެއްގައި ކްރައުން އެންޑް ޗަމްޕާ ރިސޯޓްސްގެ ޗެއާމަން އަފީފު ވިދާޅުވީ ބޭންކެއް ހެދުމުގެ ވިސްނުމަކީ އަފީފްގެ ބޭބެ، މަޝްހޫރު ވިޔަފާރިވެރިޔާ، މުހައްމަދު މޫސާ (އުއްޗު) ގެ ވިސްނުމެއް ކަމަށެވެ. އަފީފް ވިދާޅުވީ އެންމެ ފުރަތަމަ ރިސޯޓް ހަދަން މަސައްކަތް ކުރެއްވި އިރު އޭރު ރާއްޖޭގައި އިންޓަރެސްޓް ރޭޓް އުޅެނީ ވަރަށް ބޮޑު ކަމަށާއި އެކަމުގެ ސަބަބުން ވިޔަފާރި ފުޅާ ކުރަން ލޯނު ނެގުން އޮތީ ދަތިކަމަކަށް ވެފައި ކަމަށެވެ. އަދި ބޭންކެއް ހެދުމުގެ ހުވަފެން އައީ، މި ދާއިރާއަށް ވާދަވެރިކަން ގެނެސްގެން ލޯނު ފަދަ ފައިނޭންސް ލިބޭނެ އިންތިޒާމް ހަމަޖެއްސުމުގެ ވިސްނުމުގައި ކަމަށެވެ.\n',
#   'އަވަސް އަށް ދެއްވި ހާއްސަނ [MASK]ެއްގައި ކްރައުން އެންޑް ޗަމްޕާ ރިސޯޓްސްގެ ޗެއާމަން އަފީފު ވިދާޅުވީ ބޭންކެއް ހެދުމުގެ ވިސްނުމަކީ އަފީފްގެ ބޭބެ ، މަޝްހޫރު ވިޔަފާރިވެރިޔާ ، މުހައްމަދު މޫސާ ( އުއްޗު ) ގެ ވިސްނުމެއް ކަމަށެވެ. އަފީފް ވިދާޅުވީ އެންމެ ފުރަތަމަ ރިސޯޓް ހަދަން މަސައްކަތް ކުރެއްވި އިރު އޭރު ރާއްޖޭގައި އިންޓަރެސްޓް ރޭޓް އުޅެނީ ވަރަށް ބޮޑު ކަމަށާއި އެކަމުގެ ސަބަބުން ވިޔަފާރި ފުޅާ ކުރަން ލޯނު ނެގުން އޮތީ ދަތިކަމަކަށް ވެފައި ކަމަށެވެ. އަދި ބޭންކެއް ހެދުމުގެ ހުވަފެން އައީ ، މި ދާއިރާއަށް ވާދަވެރިކަން ގެނެސްގެން ލޯނު ފަދަ ފައިނޭންސް ލިބޭނެ އިންތިޒާމް ހަމަޖެއްސުމުގެ ވިސްނުމުގައި ކަމަށެވެ.'),
#  ('ބޭބެ، މުހައްމަދު މޫސާ، އުއްޗު ބޭންކް އޮފް މޯލްޑިވްސް ހެދުމުގެ މާކުރީގައި ގެންގުޅުނު ހިޔާލެއް މިއީ. އަޅުގަނޑުމެން އެންމެ ފުރަތަމަ [ޓޫރިޒަމް] ވިޔަފާރިއަށް އައިރު ބޭންކުގެ އިންޓްރެސްޓް ރޭޓް އުޅެނީ 21-22 ޕަސެންޓުގައި. އެހެންވެ މި ހިޔާލުއައީ. މި އަށް ކޮމްޕެޓިޝަނެއް ދީގެން ނޫނީ އަޅުގަނޑަށް އެނގޭ އިންޓްރެސްޓް ރޭޓް ކުޑަ ނުވާނެކަން، އަފީފު ވިދާޅުވި އެވެ.\n',
#   'ބޭބެ ، މުހައްމަދު މޫސާ ، އުއްޗު ބޭންކް އޮފް މޯލްޑިވްސް ހެދުމުގެ މާކުރީގައި ގެންގުޅުނު ހިޔާލެއް މިއީ. އަޅުގަނޑުމެން އެންމެ ފުރަތަމަ [ ޓޫރިޒަމް ] ވިޔަފާރިއަށް އައިރު ބޭންކުގެ އިންޓްރެސްޓް ރޭޓް އުޅެނީ 21 - 22 ޕަސެންޓުގައި. އެހެންވެ މި ހިޔާލުއައީ. މި އަށް ކޮމްޕ [MASK]ިޝަނެއް ދީގެން ނޫނީ އަޅުގަނޑަށް އެނގޭ އިންޓްރެސްޓް ރޭޓް ކުޑަ ނުވާނެކަން ، އަފީފު ވިދާޅުވި އެވެ.'),
#  ('ސީބީއެމް ހަދާފައިވަނީ ދުނިޔޭގެ އެކި ހިސާބުތަކުގައި 200 އެއްހާ ބްރާންޗު ހިންގާ، ސްރީ ލަންކާގެ ކޮމާޝަލް ބޭންކްގެ 55 ޕަސެންޓް ހިއްސާ އާއި ސީބީއެމްގައި ޓްރީ ޓޮޕްގެ 45 ޕަސެންޓް ހިއްސާ އޮންނަ ގޮތަށެވެ. މި ބޭންކް ހުޅުވާފައިވަނީ ގާތްގަނޑަކަށް 150 މިލިއަން ރުފިޔާގެ ރައުސުލްމާލަކުންނެވެ.\n',
#   'ސީބީއެމް ހަދާފައިވަނީ ދުނިޔޭގެ އެކި ހިސާބުތަކުގައި 200 އެއްހާ ބްރާންޗު ހިންގާ [MASK] ސްރީ ލަންކާގެ ކޮމާޝަލް ބޭންކްގެ 55 ޕަސެންޓް ހިއްސާ އާއި ސީބީއެމްގައި ޓްރީ ޓޮޕްގެ 45 ޕަސެންޓް ހިއްސާ އޮންނަ ގޮތަށެވެ. މި ބޭންކް ހުޅުވާފައިވަނީ ގާތްގަނޑަކަށް 150 މިލިއަން ރުފިޔާގެ ރައުސުލްމާލަކުންނެވެ.'),
#  ('އަފީފު ވިދާޅުވީ ބޭންކްތައް ގިނަވެ، ވާދަވެރިކަން ބޮޑުވާނަމަ އިންޓަރެސްޓް ރޭޓް ކުޑަ ކުރުމަށް އެހީއަކަށްވާނެ ކަމަށެވެ. އަދި ސީބީއެމްގެ މައިގަނޑު މަގުސަދަކީ ވެސް އެއީ ކަމަށް އަފީފު ވިދާޅުވި އެވެ.\n',
#   'އަފީފު ވިދާޅުވީ ބޭންކްތައް ގިނަވެ ، ވާދަވެރިކަން ބޮޑުވާނަމަ އިންޓަރެސްޓް ރޭޓް ކުޑަ ކުރުމަށް އެހީއަކަށްވާނެ ކަމަށެވެ. އަދި ސީބީއެމްގެ މައިގަނޑު މަގުސަދަކީ ވެސް އެއީ ކަމަށް [MASK] ވިދާޅުވި އެވެ.')]

# %%
for sentence in samples:
    #print(sentence[0])
    print(sentence[1].replace('[MASK]', '[މާސްކް]'))  # dhivehi is written in opposite direction, printing w/ english messes up order
    #print('---')
    preds = fill_mask(sentence[1])
    for pred in preds:
        print(pred['sequence'])
    print('-----------')
# Out:
# ބޭންކު ހެދީ [މާސްކް] ބޮޑުކޮށް ، އިންޓަރެސްޓް ކުޑަ ކުރަން
# ބޭންކު ހެދީ ދަރަނި ބޮޑުކޮށް ، އިންޓަރެސްޓް ކުޑަ ކުރަން
# ބޭންކު ހެދީ ހަރަދު ބޮޑުކޮށް ، އިންޓަރެސްޓް ކުޑަ ކުރަން
# ބޭންކު ހެދީ ވަރަށް ބޮޑުކޮށް ، އިންޓަރެސްޓް ކުޑަ ކުރަން
# ބޭންކު ހެދީ މުސާރަ ބޮޑުކޮށް ، އިންޓަރެސްޓް ކުޑަ ކުރަން
# ބޭންކު ހެދީ އަގު ބޮޑުކޮށް ، އިންޓަރެސްޓް ކުޑަ ކުރަން
# -----------
# ރާއްޖޭގައި އިތުރު ބޭންކެއް ހެދުމުގެ މަގުސަދަކީ ބޭންކިން ދާއިރާގެ ވާދަވެރިކަން ބޮޑުކޮށް ، [މާސްކް] ރޭޓް ކުޑަ ކުރުމަށް ބާރު އަޅަން ކަމަށް ކޮމާޝަލް ބޭންކް އޮފް މޯލްޑިވްސް ( ސީބީއެމް ) ގެ އެއް ހިއްސާދާރު އަދި މަޝްހޫރު ވިޔަފާރިވެރިޔާ ، ޗަމްޕާ ހުސެއިން އަފީފު މިއަދު ވިދާޅުވެއްޖެ އެވެ.
# ރާއްޖޭގައި އިތުރު ބޭންކެއް ހެދުމުގެ މަގުސަދަކީ ބޭންކިން ދާއިރާގެ ވާދަވެރިކަން ބޮޑުކޮށް ، އިންޓަރެސްޓް ރޭޓް ކުޑަ ކުރުމަށް ބާރު އަޅަން ކަމަށް ކޮމާޝަލް ބޭންކް އޮފް މޯލްޑިވްސް ( ސީބީއެމް ) ގެ އެއް ހިއްސާދާރު އަދި މަޝްހޫރު ވިޔަފާރިވެރިޔާ ، ޗަމްޕާ ހުސެއިން އަފީފު މިއަދު ވިދާޅުވެއްޖެ އެވެ.
# ރާއްޖޭގައި އިތުރު ބޭންކެއް ހެދުމުގެ މަގުސަދަކީ ބޭންކިން ދާއިރާގެ ވާދަވެރިކަން ބޮޑުކޮށް ، ކްރެޑިޓް ރޭޓް ކުޑަ ކުރުމަށް ބާރު އަޅަން ކަމަށް ކޮމާޝަލް ބޭންކް އޮފް މޯލްޑިވްސް ( ސީބީއެމް ) ގެ އެއް ހިއްސާދާރު އަދި މަޝްހޫރު ވިޔަފާރިވެރިޔާ ، ޗަމްޕާ ހުސެއިން އަފީފު މިއަދު ވިދާޅުވެއްޖެ އެވެ.
# ރާއްޖޭގައި އިތުރު ބޭންކެއް ހެދުމުގެ މަގުސަދަކީ ބޭންކިން ދާއިރާގެ ވާދަވެރިކަން ބޮޑުކޮށް ، އިންޓްރެސްޓް ރޭޓް ކުޑަ ކުރުމަށް ބާރު އަޅަން ކަމަށް ކޮމާޝަލް ބޭންކް އޮފް މޯލްޑިވްސް ( ސީބީއެމް ) ގެ އެއް ހިއްސާދާރު އަދި މަޝްހޫރު ވިޔަފާރިވެރިޔާ ، ޗަމްޕާ ހުސެއިން އަފީފު މިއަދު ވިދާޅުވެއްޖެ އެވެ.
# ރާއްޖޭގައި އިތުރު ބޭންކެއް ހެދުމުގެ މަގުސަދަކީ ބޭންކިން ދާއިރާގެ ވާދަވެރިކަން ބޮޑުކޮށް ، އިންފްލޭޝަން ރޭޓް ކުޑަ ކުރުމަށް ބާރު އަޅަން ކަމަށް ކޮމާޝަލް ބޭންކް އޮފް މޯލްޑިވްސް ( ސީބީއެމް ) ގެ އެއް ހިއްސާދާރު އަދި މަޝްހޫރު ވިޔަފާރިވެރިޔާ ، ޗަމްޕާ ހުސެއިން އަފީފު މިއަދު ވިދާޅުވެއްޖެ އެވެ.
# ރާއްޖޭގައި އިތުރު ބޭންކެއް ހެދުމުގެ މަގުސަދަކީ ބޭންކިން ދާއިރާގެ ވާދަވެރިކަން ބޮޑުކޮށް ، އެކްސްޗޭންޖް ރޭޓް ކުޑަ ކުރުމަށް ބާރު އަޅަން ކަމަށް ކޮމާޝަލް ބޭންކް އޮފް މޯލްޑިވްސް ( ސީބީއެމް ) ގެ އެއް ހިއްސާދާރު އަދި މަޝްހޫރު ވިޔަފާރިވެރިޔާ ، ޗަމްޕާ ހުސެއިން އަފީފު މިއަދު ވިދާޅުވެއްޖެ އެވެ.
# -----------
# އަވަސް އަށް ދެއްވި ހާއްސަނ [މާސްކް]ެއްގައި ކްރައުން އެންޑް ޗަމްޕާ ރިސޯޓްސްގެ ޗެއާމަން އަފީފު ވިދާޅުވީ ބޭންކެއް ހެދުމުގެ ވިސްނުމަކީ އަފީފްގެ ބޭބެ ، މަޝްހޫރު ވިޔަފާރިވެރިޔާ ، މުހައްމަދު މޫސާ ( އުއްޗު ) ގެ ވިސްނުމެއް ކަމަށެވެ. އަފީފް ވިދާޅުވީ އެންމެ ފުރަތަމަ ރިސޯޓް ހަދަން މަސައްކަތް ކުރެއްވި އިރު އޭރު ރާއްޖޭގައި އިންޓަރެސްޓް ރޭޓް އުޅެނީ ވަރަށް ބޮޑު ކަމަށާއި އެކަމުގެ ސަބަބުން ވިޔަފާރި ފުޅާ ކުރަން ލޯނު ނެގުން އޮތީ ދަތިކަމަކަށް ވެފައި ކަމަށެވެ. އަދި ބޭންކެއް ހެދުމުގެ ހުވަފެން އައީ ، މި ދާއިރާއަށް ވާދަވެރިކަން ގެނެސްގެން ލޯނު ފަދަ ފައިނޭންސް ލިބޭނެ އިންތިޒާމް ހަމަޖެއްސުމުގެ ވިސްނުމުގައި ކަމަށެވެ.
# އަވަސް އަށް ދެއްވި ހާއްސަނދު ެއްގައި ކްރައުން އެންޑް ޗަމްޕާ ރިސޯޓްސްގެ ޗެއާމަން އަފީފު ވިދާޅުވީ ބޭންކެއް ހެދުމުގެ ވިސްނުމަކީ އަފީފްގެ ބޭބެ ، މަޝްހޫރު ވިޔަފާރިވެރިޔާ ، މުހައްމަދު މޫސާ ( އުއްޗު ) ގެ ވިސްނުމެއް ކަމަށެވެ. އަފީފް ވިދާޅުވީ އެންމެ ފުރަތަމަ ރިސޯޓް ހަދަން މަސައްކަތް ކުރެއްވި އިރު އޭރު ރާއްޖޭގައި އިންޓަރެސްޓް ރޭޓް އުޅެނީ ވަރަށް ބޮޑު ކަމަށާއި އެކަމުގެ ސަބަބުން ވިޔަފާރި ފުޅާ ކުރަން ލޯނު ނެގުން އޮތީ ދަތިކަމަކަށް ވެފައި ކަމަށެވެ. އަދި ބޭންކެއް ހެދުމުގެ ހުވަފެން އައީ ، މި ދާއިރާއަށް ވާދަވެރިކަން ގެނެސްގެން ލޯނު ފަދަ ފައިނޭންސް ލިބޭނެ އިންތިޒާމް ހަމަޖެއްސުމުގެ ވިސްނުމުގައި ކަމަށެވެ.
# އަވަސް އަށް ދެއްވި ހާއްސަނބު ެއްގައި ކްރައުން އެންޑް ޗަމްޕާ ރިސޯޓްސްގެ ޗެއާމަން އަފީފު ވިދާޅުވީ ބޭންކެއް ހެދުމުގެ ވިސްނުމަކީ އަފީފްގެ ބޭބެ ، މަޝްހޫރު ވިޔަފާރިވެރިޔާ ، މުހައްމަދު މޫސާ ( އުއްޗު ) ގެ ވިސްނުމެއް ކަމަށެވެ. އަފީފް ވިދާޅުވީ އެންމެ ފުރަތަމަ ރިސޯޓް ހަދަން މަސައްކަތް ކުރެއްވި އިރު އޭރު ރާއްޖޭގައި އިންޓަރެސްޓް ރޭޓް އުޅެނީ ވަރަށް ބޮޑު ކަމަށާއި އެކަމުގެ ސަބަބުން ވިޔަފާރި ފުޅާ ކުރަން ލޯނު ނެގުން އޮތީ ދަތިކަމަކަށް ވެފައި ކަމަށެވެ. އަދި ބޭންކެއް ހެދުމުގެ ހުވަފެން އައީ ، މި ދާއިރާއަށް ވާދަވެރިކަން ގެނެސްގެން ލޯނު ފަދަ ފައިނޭންސް ލިބޭނެ އިންތިޒާމް ހަމަޖެއްސުމުގެ ވިސްނުމުގައި ކަމަށެވެ.
# އަވަސް އަށް ދެއްވި ހާއްސަނ ، ެއްގައި ކްރައުން އެންޑް ޗަމްޕާ ރިސޯޓްސްގެ ޗެއާމަން އަފީފު ވިދާޅުވީ ބޭންކެއް ހެދުމުގެ ވިސްނުމަކީ އަފީފްގެ ބޭބެ ، މަޝްހޫރު ވިޔަފާރިވެރިޔާ ، މުހައްމަދު މޫސާ ( އުއްޗު ) ގެ ވިސްނުމެއް ކަމަށެވެ. އަފީފް ވިދާޅުވީ އެންމެ ފުރަތަމަ ރިސޯޓް ހަދަން މަސައްކަތް ކުރެއްވި އިރު އޭރު ރާއްޖޭގައި އިންޓަރެސްޓް ރޭޓް އުޅެނީ ވަރަށް ބޮޑު ކަމަށާއި އެކަމުގެ ސަބަބުން ވިޔަފާރި ފުޅާ ކުރަން ލޯނު ނެގުން އޮތީ ދަތިކަމަކަށް ވެފައި ކަމަށެވެ. އަދި ބޭންކެއް ހެދުމުގެ ހުވަފެން އައީ ، މި ދާއިރާއަށް ވާދަވެރިކަން ގެނެސްގެން ލޯނު ފަދަ ފައިނޭންސް ލިބޭނެ އިންތިޒާމް ހަމަޖެއްސުމުގެ ވިސްނުމުގައި ކަމަށެވެ.
# އަވަސް އަށް ދެއްވި ހާއްސަނަ ެއްގައި ކްރައުން އެންޑް ޗަމްޕާ ރިސޯޓްސްގެ ޗެއާމަން އަފީފު ވިދާޅުވީ ބޭންކެއް ހެދުމުގެ ވިސްނުމަކީ އަފީފްގެ ބޭބެ ، މަޝްހޫރު ވިޔަފާރިވެރިޔާ ، މުހައްމަދު މޫސާ ( އުއްޗު ) ގެ ވިސްނުމެއް ކަމަށެވެ. އަފީފް ވިދާޅުވީ އެންމެ ފުރަތަމަ ރިސޯޓް ހަދަން މަސައްކަތް ކުރެއްވި އިރު އޭރު ރާއްޖޭގައި އިންޓަރެސްޓް ރޭޓް އުޅެނީ ވަރަށް ބޮޑު ކަމަށާއި އެކަމުގެ ސަބަބުން ވިޔަފާރި ފުޅާ ކުރަން ލޯނު ނެގުން އޮތީ ދަތިކަމަކަށް ވެފައި ކަމަށެވެ. އަދި ބޭންކެއް ހެދުމުގެ ހުވަފެން އައީ ، މި ދާއިރާއަށް ވާދަވެރިކަން ގެނެސްގެން ލޯނު ފަދަ ފައިނޭންސް ލިބޭނެ އިންތިޒާމް ހަމަޖެއްސުމުގެ ވިސްނުމުގައި ކަމަށެވެ.
# އަވަސް އަށް ދެއްވި ހާއްސަނދުގެ ެއްގައި ކްރައުން އެންޑް ޗަމްޕާ ރިސޯޓްސްގެ ޗެއާމަން އަފީފު ވިދާޅުވީ ބޭންކެއް ހެދުމުގެ ވިސްނުމަކީ އަފީފްގެ ބޭބެ ، މަޝްހޫރު ވިޔަފާރިވެރިޔާ ، މުހައްމަދު މޫސާ ( އުއްޗު ) ގެ ވިސްނުމެއް ކަމަށެވެ. އަފީފް ވިދާޅުވީ އެންމެ ފުރަތަމަ ރިސޯޓް ހަދަން މަސައްކަތް ކުރެއްވި އިރު އޭރު ރާއްޖޭގައި އިންޓަރެސްޓް ރޭޓް އުޅެނީ ވަރަށް ބޮޑު ކަމަށާއި އެކަމުގެ ސަބަބުން ވިޔަފާރި ފުޅާ ކުރަން ލޯނު ނެގުން އޮތީ ދަތިކަމަކަށް ވެފައި ކަމަށެވެ. އަދި ބޭންކެއް ހެދުމުގެ ހުވަފެން އައީ ، މި ދާއިރާއަށް ވާދަވެރިކަން ގެނެސްގެން ލޯނު ފަދަ ފައިނޭންސް ލިބޭނެ އިންތިޒާމް ހަމަޖެއްސުމުގެ ވިސްނުމުގައި ކަމަށެވެ.
# -----------
# ބޭބެ ، މުހައްމަދު މޫސާ ، އުއްޗު ބޭންކް އޮފް މޯލްޑިވްސް ހެދުމުގެ މާކުރީގައި ގެންގުޅުނު ހިޔާލެއް މިއީ. އަޅުގަނޑުމެން އެންމެ ފުރަތަމަ [ ޓޫރިޒަމް ] ވިޔަފާރިއަށް އައިރު ބޭންކުގެ އިންޓްރެސްޓް ރޭޓް އުޅެނީ 21 - 22 ޕަސެންޓުގައި. އެހެންވެ މި ހިޔާލުއައީ. މި އަށް ކޮމްޕ [މާސްކް]ިޝަނެއް ދީގެން ނޫނީ އަޅުގަނޑަށް އެނގޭ އިންޓްރެސްޓް ރޭޓް ކުޑަ ނުވާނެކަން ، އަފީފު ވިދާޅުވި އެވެ.
# ބޭބެ ، މުހައްމަދު މޫސާ ، އުއްޗު ބޭންކް އޮފް މޯލްޑިވްސް ހެދުމުގެ މާކުރީގައި ގެންގުޅުނު ހިޔާލެއް މިއީ. އަޅުގަނޑުމެން އެންމެ ފުރަތަމަ [ ޓޫރިޒަމް ] ވިޔަފާރިއަށް އައިރު ބޭންކުގެ އިންޓްރެސްޓް ރޭޓް އުޅެނީ 21 - 22 ޕަސެންޓުގައި. އެހެންވެ މި ހިޔާލުއައީ. މި އަށް ކޮމްޕެޓ ިޝަނެއް ދީގެން ނޫނީ އަޅުގަނޑަށް އެނގޭ އިންޓްރެސްޓް ރޭޓް ކުޑަ ނުވާނެކަން ، އަފީފު ވިދާޅުވި އެވެ.
# ބޭބެ ، މުހައްމަދު މޫސާ ، އުއްޗު ބޭންކް އޮފް މޯލްޑިވްސް ހެދުމުގެ މާކުރީގައި ގެންގުޅުނު ހިޔާލެއް މިއީ. އަޅުގަނޑުމެން އެންމެ ފުރަތަމަ [ ޓޫރިޒަމް ] ވިޔަފާރިއަށް އައިރު ބޭންކުގެ އިންޓްރެސްޓް ރޭޓް އުޅެނީ 21 - 22 ޕަސެންޓުގައި. އެހެންވެ މި ހިޔާލުއައީ. މި އަށް ކޮމްޕްރެ ިޝަނެއް ދީގެން ނޫނީ އަޅުގަނޑަށް އެނގޭ އިންޓްރެސްޓް ރޭޓް ކުޑަ ނުވާނެކަން ، އަފީފު ވިދާޅުވި އެވެ.
# ބޭބެ ، މުހައްމަދު މޫސާ ، އުއްޗު ބޭންކް އޮފް މޯލްޑިވްސް ހެދުމުގެ މާކުރީގައި ގެންގުޅުނު ހިޔާލެއް މިއީ. އަޅުގަނޑުމެން އެންމެ ފުރަތަމަ [ ޓޫރިޒަމް ] ވިޔަފާރިއަށް އައިރު ބޭންކުގެ އިންޓްރެސްޓް ރޭޓް އުޅެނީ 21 - 22 ޕަސެންޓުގައި. އެހެންވެ މި ހިޔާލުއައީ. މި އަށް ކޮމްޕްރ ިޝަނެއް ދީގެން ނޫނީ އަޅުގަނޑަށް އެނގޭ އިންޓްރެސްޓް ރޭޓް ކުޑަ ނުވާނެކަން ، އަފީފު ވިދާޅުވި އެވެ.
# ބޭބެ ، މުހައްމަދު މޫސާ ، އުއްޗު ބޭންކް އޮފް މޯލްޑިވްސް ހެދުމުގެ މާކުރީގައި ގެންގުޅުނު ހިޔާލެއް މިއީ. އަޅުގަނޑުމެން އެންމެ ފުރަތަމަ [ ޓޫރިޒަމް ] ވިޔަފާރިއަށް އައިރު ބޭންކުގެ އިންޓްރެސްޓް ރޭޓް އުޅެނީ 21 - 22 ޕަސެންޓުގައި. އެހެންވެ މި ހިޔާލުއައީ. މި އަށް ކޮމްޕޮސ ިޝަނެއް ދީގެން ނޫނީ އަޅުގަނޑަށް އެނގޭ އިންޓްރެސްޓް ރޭޓް ކުޑަ ނުވާނެކަން ، އަފީފު ވިދާޅުވި އެވެ.
# ބޭބެ ، މުހައްމަދު މޫސާ ، އުއްޗު ބޭންކް އޮފް މޯލްޑިވްސް ހެދުމުގެ މާކުރީގައި ގެންގުޅުނު ހިޔާލެއް މިއީ. އަޅުގަނޑުމެން އެންމެ ފުރަތަމަ [ ޓޫރިޒަމް ] ވިޔަފާރިއަށް އައިރު ބޭންކުގެ އިންޓްރެސްޓް ރޭޓް އުޅެނީ 21 - 22 ޕަސެންޓުގައި. އެހެންވެ މި ހިޔާލުއައީ. މި އަށް ކޮމްޕޮލ ިޝަނެއް ދީގެން ނޫނީ އަޅުގަނޑަށް އެނގޭ އިންޓްރެސްޓް ރޭޓް ކުޑަ ނުވާނެކަން ، އަފީފު ވިދާޅުވި އެވެ.
# -----------
# ސީބީއެމް ހަދާފައިވަނީ ދުނިޔޭގެ އެކި ހިސާބުތަކުގައި 200 އެއްހާ ބްރާންޗު ހިންގާ [މާސްކް] ސްރީ ލަންކާގެ ކޮމާޝަލް ބޭންކްގެ 55 ޕަސެންޓް ހިއްސާ އާއި ސީބީއެމްގައި ޓްރީ ޓޮޕްގެ 45 ޕަސެންޓް ހިއްސާ އޮންނަ ގޮތަށެވެ. މި ބޭންކް ހުޅުވާފައިވަނީ ގާތްގަނޑަކަށް 150 މިލިއަން ރުފިޔާގެ ރައުސުލްމާލަކުންނެވެ.
# ސީބީއެމް ހަދާފައިވަނީ ދުނިޔޭގެ އެކި ހިސާބުތަކުގައި 200 އެއްހާ ބްރާންޗު ހިންގާއިރު ސްރީ ލަންކާގެ ކޮމާޝަލް ބޭންކްގެ 55 ޕަސެންޓް ހިއްސާ އާއި ސީބީއެމްގައި ޓްރީ ޓޮޕްގެ 45 ޕަސެންޓް ހިއްސާ އޮންނަ ގޮތަށެވެ. މި ބޭންކް ހުޅުވާފައިވަނީ ގާތްގަނޑަކަށް 150 މިލިއަން ރުފިޔާގެ ރައުސުލްމާލަކުންނެވެ.
# ސީބީއެމް ހަދާފައިވަނީ ދުނިޔޭގެ އެކި ހިސާބުތަކުގައި 200 އެއްހާ ބްރާންޗު ހިންގާ އިރު ސްރީ ލަންކާގެ ކޮމާޝަލް ބޭންކްގެ 55 ޕަސެންޓް ހިއްސާ އާއި ސީބީއެމްގައި ޓްރީ ޓޮޕްގެ 45 ޕަސެންޓް ހިއްސާ އޮންނަ ގޮތަށެވެ. މި ބޭންކް ހުޅުވާފައިވަނީ ގާތްގަނޑަކަށް 150 މިލިއަން ރުފިޔާގެ ރައުސުލްމާލަކުންނެވެ.
# ސީބީއެމް ހަދާފައިވަނީ ދުނިޔޭގެ އެކި ހިސާބުތަކުގައި 200 އެއްހާ ބްރާންޗު ހިންގާ ، ސްރީ ލަންކާގެ ކޮމާޝަލް ބޭންކްގެ 55 ޕަސެންޓް ހިއްސާ އާއި ސީބީއެމްގައި ޓްރީ ޓޮޕްގެ 45 ޕަސެންޓް ހިއްސާ އޮންނަ ގޮތަށެވެ. މި ބޭންކް ހުޅުވާފައިވަނީ ގާތްގަނޑަކަށް 150 މިލިއަން ރުފިޔާގެ ރައުސުލްމާލަކުންނެވެ.
# ސީބީއެމް ހަދާފައިވަނީ ދުނިޔޭގެ އެކި ހިސާބުތަކުގައި 200 އެއްހާ ބްރާންޗު ހިންގާ އަދި ސްރީ ލަންކާގެ ކޮމާޝަލް ބޭންކްގެ 55 ޕަސެންޓް ހިއްސާ އާއި ސީބީއެމްގައި ޓްރީ ޓޮޕްގެ 45 ޕަސެންޓް ހިއްސާ އޮންނަ ގޮތަށެވެ. މި ބޭންކް ހުޅުވާފައިވަނީ ގާތްގަނޑަކަށް 150 މިލިއަން ރުފިޔާގެ ރައުސުލްމާލަކުންނެވެ.
# ސީބީއެމް ހަދާފައިވަނީ ދުނިޔޭގެ އެކި ހިސާބުތަކުގައި 200 އެއްހާ ބްރާންޗު ހިންގާ ކުންފުނި ސްރީ ލަންކާގެ ކޮމާޝަލް ބޭންކްގެ 55 ޕަސެންޓް ހިއްސާ އާއި ސީބީއެމްގައި ޓްރީ ޓޮޕްގެ 45 ޕަސެންޓް ހިއްސާ އޮންނަ ގޮތަށެވެ. މި ބޭންކް ހުޅުވާފައިވަނީ ގާތްގަނޑަކަށް 150 މިލިއަން ރުފިޔާގެ ރައުސުލްމާލަކުންނެވެ.
# -----------
# އަފީފު ވިދާޅުވީ ބޭންކްތައް ގިނަވެ ، ވާދަވެރިކަން ބޮޑުވާނަމަ އިންޓަރެސްޓް ރޭޓް ކުޑަ ކުރުމަށް އެހީއަކަށްވާނެ ކަމަށެވެ. އަދި ސީބީއެމްގެ މައިގަނޑު މަގުސަދަކީ ވެސް އެއީ ކަމަށް [މާސްކް] ވިދާޅުވި އެވެ.
# އަފީފު ވިދާޅުވީ ބޭންކްތައް ގިނަވެ ، ވާދަވެރިކަން ބޮޑުވާނަމަ އިންޓަރެސްޓް ރޭޓް ކުޑަ ކުރުމަށް އެހީއަކަށްވާނެ ކަމަށެވެ. އަދި ސީބީއެމްގެ މައިގަނޑު މަގުސަދަކީ ވެސް އެއީ ކަމަށް އޭނާ ވިދާޅުވި އެވެ.
# އަފީފު ވިދާޅުވީ ބޭންކްތައް ގިނަވެ ، ވާދަވެރިކަން ބޮޑުވާނަމަ އިންޓަރެސްޓް ރޭޓް ކުޑަ ކުރުމަށް އެހީއަކަށްވާނެ ކަމަށެވެ. އަދި ސީބީއެމްގެ މައިގަނޑު މަގުސަދަކީ ވެސް އެއީ ކަމަށް އަފީފު ވިދާޅުވި އެވެ.
# އަފީފު ވިދާޅުވީ ބޭންކްތައް ގިނަވެ ، ވާދަވެރިކަން ބޮޑުވާނަމަ އިންޓަރެސްޓް ރޭޓް ކުޑަ ކުރުމަށް އެހީއަކަށްވާނެ ކަމަށެވެ. އަދި ސީބީއެމްގެ މައިގަނޑު މަގުސަދަކީ ވެސް އެއީ ކަމަށް އަފީފް ވިދާޅުވި އެވެ.
# އަފީފު ވިދާޅުވީ ބޭންކްތައް ގިނަވެ ، ވާދަވެރިކަން ބޮޑުވާނަމަ އިންޓަރެސްޓް ރޭޓް ކުޑަ ކުރުމަށް އެހީއަކަށްވާނެ ކަމަށެވެ. އަދި ސީބީއެމްގެ މައިގަނޑު މަގުސަދަކީ ވެސް އެއީ ކަމަށް ވެސް ވިދާޅުވި އެވެ.
# އަފީފު ވިދާޅުވީ ބޭންކްތައް ގިނަވެ ، ވާދަވެރިކަން ބޮޑުވާނަމަ އިންޓަރެސްޓް ރޭޓް ކުޑަ ކުރުމަށް އެހީއަކަށްވާނެ ކަމަށެވެ. އަދި ސީބީއެމްގެ މައިގަނޑު މަގުސަދަކީ ވެސް އެއީ ކަމަށް ސައީދު ވިދާޅުވި އެވެ.
# -----------
